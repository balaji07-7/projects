# %% [markdown]
# # PREDICTIVE MAINTENANCE ANALYSIS

# %% [markdown]
# <img src='pred1.jpg' width=500>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('/content/predictive_maintenance.csv')
df
# Out:
#         UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860    M                298.1                    308.6
# 1         2     L47181    L                298.2                    308.7
# 2         3     L47182    L                298.1                    308.5
# 3         4     L47183    L                298.2                    308.6
# 4         5     L47184    L                298.2                    308.7
# ...     ...        ...  ...                  ...                      ...
# 9995   9996     M24855    M                298.8                    308.4
# 9996   9997     H39410    H                298.9                    308.4
# 9997   9998     M24857    M                299.0                    308.6
# 9998   9999     H39412    H                299.0                    308.7
# 9999  10000     M24859    M                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
#      Failure Type
# 0      No Failure
# 1      No Failure
# 2      No Failure
# 3      No Failure
# 4      No Failure
# ...           ...
# 9995   No Failure
# 9996   No Failure
# 9997   No Failure
# 9998   No Failure
# 9999   No Failure
#
# [10000 rows x 10 columns]

# %% [markdown]
# ### Data Description

# %% [markdown]
# <img src='drill (2).jpg' width=600>

# %% [markdown]
# - After looking at the dataset, we can assume that the data is about the drilling tool used in a lathe machine.
# - The columns consist values of:
#     1. Air temperature in Kelvin (K)
#     2. Process temperature in Kelvin (K)
#     3. Rotational speed in Rotation per minute (RPM)
#     4. Torque in Newton meters (Nm)
#     5. Tool wear in minutes (min)
# - Type column is given to represent the type of product with respect to its quality.
# >L, M and H are for Low, Medium and High quality products respectively.
# - ProductID consisting of a letter L, M, or H for low (50% of all products), medium (30%), and high (20%) as product quality variants and a variant-specific serial number.
# - The target column is the output of machine, if it is failing or not.
# >0 represents no failure whereas 1 represents that failure has occured.
# - An additional column of Failure Type is given so that we can understand what type of failure is occuring.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   UDI                      10000 non-null  int64
#  1   Product ID               10000 non-null  object
#  2   Type                     10000 non-null  object
#  3   Air temperature [K]      10000 non-null  float64
#  4   Process temperature [K]  10000 non-null  float64
#  5   Rotational speed [rpm]   10000 non-null  int64
#  6   Torque [Nm]              10000 non-null  float64
#  7   Tool wear [min]          10000 non-null  int64
#  8   Target                   10000 non-null  int64
#  9   Failure Type             10000 non-null  object
# dtypes: float64(3), int64(4), object(3)
# memory usage: 781.4+ KB

# %%
# prompt: drop udi

df.drop('UDI', axis=1,inplace=True)

# %%
df.describe()
# Out:
#        Air temperature [K]  Process temperature [K]  Rotational speed [rpm]  \
# count         10000.000000             10000.000000            10000.000000
# mean            300.004930               310.005560             1538.776100
# std               2.000259                 1.483734              179.284096
# min             295.300000               305.700000             1168.000000
# 25%             298.300000               308.800000             1423.000000
# 50%             300.100000               310.100000             1503.000000
# 75%             301.500000               311.100000             1612.000000
# max             304.500000               313.800000             2886.000000
#
#         Torque [Nm]  Tool wear [min]        Target
# count  10000.000000     10000.000000  10000.000000
# mean      39.986910       107.951000      0.033900
# std        9.968934        63.654147      0.180981
# min        3.800000         0.000000      0.000000
# 25%       33.200000        53.000000      0.000000
# 50%       40.100000       108.000000      0.000000
# 75%       46.800000       162.000000      0.000000
# max       76.600000       253.000000      1.000000

# %% [markdown]
# _The above table shows us that our data is normally distributed since all the mean and median values are close to each other. So there is no need for skewness removal._

# %%
df['Target'].value_counts()
# Out:
# Target
# 0    9661
# 1     339
# Name: count, dtype: int64

# %%
df['Target'].value_counts().plot.pie(explode=[0.1,0.1],autopct='%.1f%%',title="Machine Failure")
# Out:
# <Axes: title={'center': 'Machine Failure'}, ylabel='count'>

# %% [markdown]
# _The above Pie chart shows that only 3.4
# % of times our machine is failing. Though the failure rate is very low in comparison to success rate, we still need to avoid any failure in order to improve productivity of the machine._

# %%
df['Failure Type'].value_counts()
# Out:
# Failure Type
# No Failure                  9652
# Heat Dissipation Failure     112
# Power Failure                 95
# Overstrain Failure            78
# Tool Wear Failure             45
# Random Failures               18
# Name: count, dtype: int64

# %% [markdown]
# Here we can see the types of failures such as:
#   1. Heat Dissipation Failure : The failure that occurs due to overheating of the tool.
#   2. Power Failure : The failure occuring due to power cutout.
#   3. Overstrain Failure : Failure because of excessive strain on the tool.
#   4. Tool Wear Failure : Failure due to tool wear and tear that happens after excessive use of tool.
#   5. Random Failures : Random Failures can be any failure whose cause can't be assessed or any human error.
#
# "No failure" as the name suggests means there is no failure of machine

# %%
plt.figure(figsize = (8,8))
sns.countplot(data = df[df['Target'] == 1], x = "Failure Type")
plt.title("Count of Failures W.R.T Failure Types")
plt.show()

# %% [markdown]
# _In the above countplot we can see that "No Failure" is also plotted but that does not makes any sense. This means there are some fake values in the data. So we need to eliminate them._

# %%
df[(df['Target']==1) & (df['Failure Type']=='No Failure')]
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 1437  1438     H30851    H                298.8                    309.9
# 2749  2750     M17609    M                299.7                    309.2
# 4044  4045     M18904    M                301.9                    310.9
# 4684  4685     M19544    M                303.6                    311.8
# 5536  5537     M20396    M                302.3                    311.8
# 5941  5942     L53121    L                300.6                    310.7
# 6478  6479     L53658    L                300.5                    309.8
# 8506  8507     L55686    L                298.4                    309.6
# 9015  9016     L56195    L                297.2                    308.1
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 1437                    1439         45.2               40       1
# 2749                    1685         28.9              179       1
# 4044                    1419         47.7               20       1
# 4684                    1421         44.8              101       1
# 5536                    1363         54.0              119       1
# 5941                    1438         48.5               78       1
# 6478                    1663         29.1              145       1
# 8506                    1710         27.3              163       1
# 9015                    1431         49.7              210       1
#
#      Failure Type
# 1437   No Failure
# 2749   No Failure
# 4044   No Failure
# 4684   No Failure
# 5536   No Failure
# 5941   No Failure
# 6478   No Failure
# 8506   No Failure
# 9015   No Failure

# %%
i = df[(df['Target']==1) & (df['Failure Type']=='No Failure')].index
df.drop(i,axis=0,inplace=True)

# %% [markdown]
# _Also, we cannot see anything related to Random Failures since they cannot be assesed. So we will drop the products with Random failures._

# %%
df[(df['Target']==0) & (df['Failure Type']=='Random Failures')]
# Out:
#        UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 1221  1222     M16081    M                297.0                    308.3
# 1302  1303     L48482    L                298.6                    309.8
# 1748  1749     H31162    H                298.4                    307.7
# 2072  2073     L49252    L                299.6                    309.5
# 2559  2560     L49739    L                299.3                    309.0
# 3065  3066     M17925    M                300.1                    309.2
# 3452  3453     H32866    H                301.6                    310.5
# 5471  5472     L52651    L                302.7                    312.3
# 5489  5490     L52669    L                302.6                    312.1
# 5495  5496     H34909    H                302.9                    312.5
# 5509  5510     L52689    L                302.8                    312.2
# 5553  5554     L52733    L                302.5                    311.9
# 5639  5640     L52819    L                302.6                    312.1
# 6091  6092     L53271    L                300.9                    310.7
# 6913  6914     L54093    L                300.8                    311.2
# 6960  6961     L54140    L                300.7                    311.0
# 7488  7489     L54668    L                300.3                    311.7
# 7868  7869     H37282    H                300.4                    311.9
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target  \
# 1221                    1399         46.4              132       0
# 1302                    1505         45.7              144       0
# 1748                    1626         31.1              166       0
# 2072                    1570         35.5              189       0
# 2559                    1447         50.4              140       0
# 3065                    1687         27.7               95       0
# 3452                    1602         32.3                2       0
# 5471                    1346         61.2              170       0
# 5489                    1499         35.0              215       0
# 5495                    1357         55.0               12       0
# 5509                    1509         36.5               52       0
# 5553                    1306         59.7              172       0
# 5639                    1668         28.7              180       0
# 6091                    1412         57.5               16       0
# 6913                    1481         38.5              181       0
# 6960                    1413         52.0               91       0
# 7488                    1545         43.5              160       0
# 7868                    1438         46.7               41       0
#
#          Failure Type
# 1221  Random Failures
# 1302  Random Failures
# 1748  Random Failures
# 2072  Random Failures
# 2559  Random Failures
# 3065  Random Failures
# 3452  Random Failures
# 5471  Random Failures
# 5489  Random Failures
# 5495  Random Failures
# 5509  Random Failures
# 5553  Random Failures
# 5639  Random Failures
# 6091  Random Failures
# 6913  Random Failures
# 6960  Random Failures
# 7488  Random Failures
# 7868  Random Failures

# %%
i = df[(df['Target']==0) & (df['Failure Type']=='Random Failures')].index
df.drop(i,axis=0,inplace=True)

# %%
plt.figure(figsize = (8,8))
sns.countplot(data = df[df['Target'] == 1], x = "Failure Type")
plt.title("Count of Failures W.R.T Failure Types")
plt.show()

# %% [markdown]
# _Here we can see that most of our failures are  __Heat Dissipation Failure__, then __Power Failure__ followed by __Overstrain__ and __Tool Wear Failures__._

# %%
df['Type'].value_counts().plot(kind='pie',autopct='%.f%%',title="Percentage of Product Types")
# Out:
# <Axes: title={'center': 'Percentage of Product Types'}, ylabel='count'>

# %% [markdown]
# _We can see that most of our products i.e. 60%, belong to low quality category. 30% belong to medium quality and 10% to high quality categories._

# %%
pd.DataFrame(df["Type"].value_counts())
# Out:
#       count
# Type
# L      5984
# M      2991
# H       998

# %%
numeric_df = df.select_dtypes(include=['number'])
sns.heatmap(numeric_df.corr(),annot=True,fmt=".2f")
# Out:
# <Axes: >

# %% [markdown]
# _From above heatmap, we can see that there is no correlation between any two columns._

# %%
df.head(1)
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure

# %%
colname=df.iloc[:,2:8].columns

# %%
import matplotlib.pyplot as plt
import seaborn as sns

for i in colname:
    print(i)
    sns.lineplot(x=df[i], y=df['Target'])
    plt.show()
# Out:
# Type
# Air temperature [K]
# Process temperature [K]
# Rotational speed [rpm]
# Torque [Nm]
# Tool wear [min]

# %% [markdown]
# _Here we can see that Rotational speed [rpm], Torque [Nm], Tool wear [min] are highly affecting our Target column_

# %%
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df.head()
# Out:
#    UDI Product ID Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860    M                298.1                    308.6
# 1    2     L47181    L                298.2                    308.7
# 2    3     L47182    L                298.1                    308.5
# 3    4     L47183    L                298.2                    308.6
# 4    5     L47184    L                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
df["Type"] = df["Type"].replace("L",0)
df["Type"] = df["Type"].replace("M",1)
df["Type"] = df["Type"].replace("H",2)

# %% [markdown]
# _Replacing the categorical values of Type column into numeric values._

# %%
df.head()
# Out:
#    UDI Product ID  Type  Air temperature [K]  Process temperature [K]  \
# 0    1     M14860     1                298.1                    308.6
# 1    2     L47181     0                298.2                    308.7
# 2    3     L47182     0                298.1                    308.5
# 3    4     L47183     0                298.2                    308.6
# 4    5     L47184     0                298.2                    308.7
#
#    Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target Failure Type
# 0                    1551         42.8                0       0   No Failure
# 1                    1408         46.3                3       0   No Failure
# 2                    1498         49.4                5       0   No Failure
# 3                    1433         39.5                7       0   No Failure
# 4                    1408         40.0                9       0   No Failure

# %%
predictors = df.iloc[:,:-1]
predictors
# Out:
#         UDI Product ID  Type  Air temperature [K]  Process temperature [K]  \
# 0         1     M14860     1                298.1                    308.6
# 1         2     L47181     0                298.2                    308.7
# 2         3     L47182     0                298.1                    308.5
# 3         4     L47183     0                298.2                    308.6
# 4         5     L47184     0                298.2                    308.7
# ...     ...        ...   ...                  ...                      ...
# 9995   9996     M24855     1                298.8                    308.4
# 9996   9997     H39410     2                298.9                    308.4
# 9997   9998     M24857     1                299.0                    308.6
# 9998   9999     H39412     2                299.0                    308.7
# 9999  10000     M24859     1                299.0                    308.7
#
#       Rotational speed [rpm]  Torque [Nm]  Tool wear [min]  Target
# 0                       1551         42.8                0       0
# 1                       1408         46.3                3       0
# 2                       1498         49.4                5       0
# 3                       1433         39.5                7       0
# 4                       1408         40.0                9       0
# ...                      ...          ...              ...     ...
# 9995                    1604         29.5               14       0
# 9996                    1632         31.8               17       0
# 9997                    1645         33.4               22       0
# 9998                    1408         48.5               25       0
# 9999                    1500         40.2               30       0
#
# [9973 rows x 9 columns]

# %%
label = df.iloc[:,-1]
label
# Out:
# 0       No Failure
# 1       No Failure
# 2       No Failure
# 3       No Failure
# 4       No Failure
#            ...
# 9995    No Failure
# 9996    No Failure
# 9997    No Failure
# 9998    No Failure
# 9999    No Failure
# Name: Failure Type, Length: 9973, dtype: object

# %% [markdown]
# ### Splitting data into train and test

# %%
# Select only numeric columns for predictors, excluding 'UDI', 'Product ID', and 'Failure Type'
numeric_cols = df.select_dtypes(include=['number']).columns
predictors = df[numeric_cols].drop(columns=['UDI', 'Target']) # Exclude UDI and Target from predictors
label = df['Failure Type'] # Use 'Failure Type' as the label

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(predictors,label,test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
from sklearn.metrics import accuracy_score,classification_report

# %%
def mymodel(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    print(classification_report(y_test,y_pred))
    return model

# %% [markdown]
# # **_Here we created a function to check which Machine Learning Algorithm will be the best fit for our model. We will select the one with highest accuracy._**

# %%
mymodel(logreg)
# Out:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.00      0.00      0.00        32
#               No Failure       0.98      1.00      0.99      2903
#       Overstrain Failure       0.40      0.31      0.35        13
#            Power Failure       0.90      0.56      0.69        32
#        Tool Wear Failure       0.17      0.08      0.11        12
#
#                 accuracy                           0.98      2992
#                macro avg       0.49      0.39      0.43      2992
#             weighted avg       0.96      0.98      0.97      2992
# LogisticRegression()

# %%
mymodel(knn)
# Out:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.00      0.00      0.00        32
#               No Failure       0.98      1.00      0.99      2903
#       Overstrain Failure       0.23      0.23      0.23        13
#            Power Failure       0.83      0.31      0.45        32
#        Tool Wear Failure       0.00      0.00      0.00        12
#
#                 accuracy                           0.97      2992
#                macro avg       0.41      0.31      0.33      2992
#             weighted avg       0.96      0.97      0.96      2992
# KNeighborsClassifier()

# %%
mymodel(dt)
# Out:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.88      0.94      0.91        32
#               No Failure       0.99      0.99      0.99      2903
#       Overstrain Failure       0.33      0.54      0.41        13
#            Power Failure       0.82      0.88      0.85        32
#        Tool Wear Failure       0.14      0.25      0.18        12
#
#                 accuracy                           0.98      2992
#                macro avg       0.63      0.72      0.67      2992
#             weighted avg       0.98      0.98      0.98      2992
# DecisionTreeClassifier()

# %%
from sklearn.svm import SVC
svm = SVC()
mymodel(svm)
# Out:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.00      0.00      0.00        32
#               No Failure       0.97      1.00      0.99      2903
#       Overstrain Failure       0.00      0.00      0.00        13
#            Power Failure       1.00      0.03      0.06        32
#        Tool Wear Failure       0.00      0.00      0.00        12
#
#                 accuracy                           0.97      2992
#                macro avg       0.39      0.21      0.21      2992
#             weighted avg       0.95      0.97      0.96      2992
# SVC()

# %% [markdown]
# # _We can see that Decision Tree Classifier is best suited for our model since it has the highest accuracy of all i.e. 98%_

# %%
print(dt.score(X_train,y_train))
print(dt.score(X_test,y_test))
# Out:
# 1.0
# 0.9796122994652406

# %% [markdown]
# _Our training and testing scores are a little different from each other. But we need scores close to each other for our model to work best._

# %% [markdown]
# ### Hyperparameter Tuning

# %%
for i in range(1,51):
    dt1 = DecisionTreeClassifier(max_depth=i)
    dt1.fit(X_train,y_train)
    y_pred = dt1.predict(X_test)
    print(f"{i} = {accuracy_score(y_test,y_pred)}")
# Out:
# 1 = 0.9742647058823529
# 2 = 0.9759358288770054
# 3 = 0.9766042780748663
# 4 = 0.9779411764705882
# 5 = 0.9809491978609626
# 6 = 0.9789438502673797
# 7 = 0.9832887700534759
# 8 = 0.9849598930481284
# 9 = 0.9852941176470589
# 10 = 0.9846256684491979
# 11 = 0.983957219251337
# 12 = 0.982620320855615
# 13 = 0.9829545454545454
# 14 = 0.981951871657754
# 15 = 0.981951871657754
# 16 = 0.9799465240641712
# 17 = 0.9816176470588235
# 18 = 0.9809491978609626
# 19 = 0.9802807486631016
# 20 = 0.9816176470588235
# 21 = 0.9796122994652406
# 22 = 0.9809491978609626
# 23 = 0.9806149732620321
# 24 = 0.9812834224598931
# 25 = 0.9812834224598931
# 26 = 0.9796122994652406
# 27 = 0.9812834224598931
# 28 = 0.9812834224598931
# 29 = 0.9816176470588235
# 30 = 0.9816176470588235
# 31 = 0.9809491978609626
# 32 = 0.9789438502673797
# 33 = 0.9799465240641712
# 34 = 0.9799465240641712
# 35 = 0.9806149732620321
# 36 = 0.982620320855615
# 37 = 0.9812834224598931
# 38 = 0.9812834224598931
# 39 = 0.9812834224598931
# 40 = 0.9802807486631016
# 41 = 0.9799465240641712
# 42 = 0.9806149732620321
# 43 = 0.9812834224598931
# 44 = 0.9799465240641712
# 45 = 0.9799465240641712
# 46 = 0.9796122994652406
# 47 = 0.981951871657754
# 48 = 0.9796122994652406
# 49 = 0.9806149732620321
# 50 = 0.9786096256684492

# %% [markdown]
# _Here, the maximum accuracy is on index 8, so we will select max_depth = 8_

# %%
for i in range(2,51):
    dt2 = DecisionTreeClassifier(min_samples_split=i)
    dt2.fit(X_train,y_train)
    y_pred = dt2.predict(X_test)
    print(f"{i} = {accuracy_score(y_test,y_pred)}")
# Out:
# 2 = 0.9792780748663101
# 3 = 0.9806149732620321
# 4 = 0.9829545454545454
# 5 = 0.9809491978609626
# 6 = 0.982620320855615
# 7 = 0.9816176470588235
# 8 = 0.9816176470588235
# 9 = 0.9816176470588235
# 10 = 0.9829545454545454
# 11 = 0.982620320855615
# 12 = 0.9822860962566845
# 13 = 0.9822860962566845
# 14 = 0.9812834224598931
# 15 = 0.981951871657754
# 16 = 0.9816176470588235
# 17 = 0.982620320855615
# 18 = 0.982620320855615
# 19 = 0.983957219251337
# 20 = 0.9832887700534759
# 21 = 0.983957219251337
# 22 = 0.982620320855615
# 23 = 0.982620320855615
# 24 = 0.9822860962566845
# 25 = 0.9822860962566845
# 26 = 0.981951871657754
# 27 = 0.982620320855615
# 28 = 0.982620320855615
# 29 = 0.982620320855615
# 30 = 0.982620320855615
# 31 = 0.9816176470588235
# 32 = 0.9816176470588235
# 33 = 0.9822860962566845
# 34 = 0.9816176470588235
# 35 = 0.9816176470588235
# 36 = 0.9822860962566845
# 37 = 0.9816176470588235
# 38 = 0.9816176470588235
# 39 = 0.9822860962566845
# 40 = 0.9806149732620321
# 41 = 0.9806149732620321
# 42 = 0.9806149732620321
# 43 = 0.9806149732620321
# 44 = 0.981951871657754
# 45 = 0.9812834224598931
# 46 = 0.9812834224598931
# 47 = 0.9812834224598931
# 48 = 0.9816176470588235
# 49 = 0.9809491978609626
# 50 = 0.9816176470588235

# %% [markdown]
# _Here, the maximum accuracy is on index 34, so we will select min_samples_split = 34_

# %%
for i in range(1,51):
    dt3 = DecisionTreeClassifier(min_samples_leaf=i)
    dt3.fit(X_train,y_train)
    y_pred = dt3.predict(X_test)
    print(f"{i} = {accuracy_score(y_test,y_pred)}")
# Out:
# 1 = 0.981951871657754
# 2 = 0.9846256684491979
# 3 = 0.9822860962566845
# 4 = 0.9802807486631016
# 5 = 0.9809491978609626
# 6 = 0.9816176470588235
# 7 = 0.9812834224598931
# 8 = 0.981951871657754
# 9 = 0.982620320855615
# 10 = 0.981951871657754
# 11 = 0.9802807486631016
# 12 = 0.9802807486631016
# 13 = 0.9786096256684492
# 14 = 0.9799465240641712
# 15 = 0.9799465240641712
# 16 = 0.9799465240641712
# 17 = 0.9799465240641712
# 18 = 0.9799465240641712
# 19 = 0.9809491978609626
# 20 = 0.9809491978609626
# 21 = 0.9832887700534759
# 22 = 0.9832887700534759
# 23 = 0.9829545454545454
# 24 = 0.9829545454545454
# 25 = 0.9829545454545454
# 26 = 0.982620320855615
# 27 = 0.9822860962566845
# 28 = 0.9822860962566845
# 29 = 0.9822860962566845
# 30 = 0.9812834224598931
# 31 = 0.9799465240641712
# 32 = 0.9799465240641712
# 33 = 0.9799465240641712
# 34 = 0.9772727272727273
# 35 = 0.9772727272727273
# 36 = 0.9769385026737968
# 37 = 0.9759358288770054
# 38 = 0.9759358288770054
# 39 = 0.9759358288770054
# 40 = 0.9759358288770054
# 41 = 0.9759358288770054
# 42 = 0.9759358288770054
# 43 = 0.9759358288770054
# 44 = 0.9759358288770054
# 45 = 0.9749331550802139
# 46 = 0.9776069518716578
# 47 = 0.9776069518716578
# 48 = 0.9776069518716578
# 49 = 0.9776069518716578
# 50 = 0.9776069518716578

# %% [markdown]
# _Here, the maximum accuracy is on index 12, so we will select min_samples_leaf = 12_

# %%
dt4 = DecisionTreeClassifier(max_depth=8,min_samples_leaf=34,min_samples_split=12)
mymodel(dt4)
# Out:
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.78      0.44      0.56        32
#               No Failure       0.99      0.99      0.99      2903
#       Overstrain Failure       0.18      0.15      0.17        13
#            Power Failure       0.65      0.81      0.72        32
#        Tool Wear Failure       0.00      0.00      0.00        12
#
#                 accuracy                           0.98      2992
#                macro avg       0.52      0.48      0.49      2992
#             weighted avg       0.97      0.98      0.97      2992
# DecisionTreeClassifier(max_depth=8, min_samples_leaf=34, min_samples_split=12)

# %%
print(dt4.score(X_train,y_train))
print(dt4.score(X_test,y_test))
# Out:
# 0.9766509096118035
# 0.9772727272727273

# %% [markdown]
# _Now, we are getting both training and testing scores almost equal._

# %% [markdown]
# ### Creating model

# %%
def predtest():
    Type = int(input("Enter type of product based on quality.\nIf Low, enter 0.\nIf Medium, enter 1.\nIf High, enter 2.\nYou entered : "))
    Airtemp = eval(input("Enter Air Temperature in K : "))
    Protemp = eval(input("Enter Process Temperature in K : "))
    Rotsp = int(input("Enter Rotational Speed in RPM : "))
    Torq = eval(input("Enter Torque in Nm : "))
    Toolw = int(input("Enter Tool Wear in min : "))
    Tempdiff = Protemp-Airtemp

    newx = [Type,Airtemp,Protemp,Rotsp,Torq,Toolw]
    yp = dt4.predict([newx])[0]

    if yp==1:
        print("Machine Failed")
        return yp
    else:
        print("Machine didn't Fail")
        return yp

# %% [markdown]
# _In order to check if our model is working properly or not, we need to test it._

# %% [markdown]
# _Here we have some existing values of the given parameters for testing failure._

# %% [markdown]
# ### Model testing

# %% [markdown]
# __Testing if our model is properly working or not.__

# %% [markdown]
# >Example:-
# - Type = M
# - Air temperature [K] = 298.2
# - Process temperature [K] = 308.5
# - Rotational speed [rpm] = 2678
# - Torque [Nm] = 10.7
# - Tool wear [min] = 86
# - Target = 1

# %% [markdown]
# __Here the machine should fail.__

# %%
predtest()
# Out:
# Enter type of product based on quality.
# If Low, enter 0.
# If Medium, enter 1.
# If High, enter 2.
# You entered : 8
# Enter Air Temperature in K : 288
# Enter Process Temperature in K : 306
# Enter Rotational Speed in RPM : 1700
# Enter Torque in Nm : 34
# Enter Tool Wear in min : 22
# Machine didn't Fail
# 'No Failure'

# %% [markdown]
# >Example:-
# - Type = H
# - Air temperature [K] = 298.4
# - Process temperature [K] = 308.9
# - Rotational speed [rpm] = 1782
# - Torque [Nm] = 23.9
# - Tool wear [min] = 24
# - Target = 0

# %% [markdown]
# __Here the machine should not fail.__

# %%
predtest()

# %% [markdown]
# _Since the outcome is correct. Our model is successful._

# %% [markdown]
# ## Prescriptive Analysis

# %% [markdown]
# - __After studying the dataset, we can see that machine failure is mainly occuring because of 3 reasons:__
#    1. Improper rotational speed of the tool.
#    2. Torque not maintained as per the requirement.
#    3. High tool wear.

# %% [markdown]
# - __Air temperature and Process temperature are not playing any major role in machine failure.__

# %% [markdown]
# - __Low quality products are more likely to fail compared to medium quality and high quality products.__

# %% [markdown]
# - __Heat dissipation failure is the most occuring failure which causes due to overheating of the tool.__

# %% [markdown]
# - __Power failure is also a major problem causing machine failure__

# %% [markdown]
# >__Measures to take in order to avoid failure.__
#    1. User must set the rotational speed properly. Not too high and also not too low.
#    2. User should not set the torque too high or too low. Torque should be set as per the tool requirement.
#    3. User should not use the same tool for long period of time. Since tools may wear due to excessive usage.
#    4. High quality and medium quality products should be used more frequently.
#    5. Overheating of tool must be avoided by constantly providing coolant to the tool.
#    6. Secondary power input should be provided in case of power failure
